# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, BatchNormalization
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import classification_report

# 📂 Step 1: Load dataset
df = pd.read_csv('/content/student_depression_dataset.csv')

# 🧹 Step 2: Data Cleaning
df.replace('?', np.nan, inplace=True)   # Replace '?' with NaN
df.drop(['id', 'City', 'Profession', 'Degree'], axis=1, inplace=True)  # Drop unnecessary cols
df.dropna(inplace=True)  # Remove rows with missing values

# 🔤 Step 3: Encode categorical columns
le = LabelEncoder()
categorical_cols = ['Gender', 'Sleep Duration', 'Dietary Habits',
                    'Have you ever had suicidal thoughts ?',
                    'Family History of Mental Illness']
for col in categorical_cols:
    df[col] = le.fit_transform(df[col])

# 🎯 Step 4: Define features and label
X = df.drop('Depression', axis=1)
y = df['Depression']

# 🔄 Step 5: Normalize numerical features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# 🧪 Step 6: Train-test split
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# 🧠 Step 7: Build Deep ANN model with Batch Normalization
model = Sequential()

# Input Layer
model.add(Dense(128, activation='relu', input_dim=X_train.shape[1]))
model.add(BatchNormalization())  # Batch Normalization after the first layer

# Hidden Layer 1
model.add(Dense(64, activation='relu'))
model.add(BatchNormalization())  # Batch Normalization after second layer

# Hidden Layer 2
model.add(Dense(32, activation='relu'))
model.add(BatchNormalization())  # Batch Normalization after third layer

# Hidden Layer 3
model.add(Dense(16, activation='relu'))
model.add(BatchNormalization())  # Batch Normalization after fourth layer

# Hidden Layer 4
model.add(Dense(8, activation='relu'))
model.add(BatchNormalization())  # Batch Normalization after fifth layer

# Output Layer
model.add(Dense(1, activation='sigmoid'))  # Binary classification

# ⚙️ Step 8: Compile the model
model.compile(optimizer=Adam(), loss='binary_crossentropy', metrics=['accuracy'])

# 🏋️ Step 9: Train the model
history = model.fit(X_train, y_train, epochs=100, batch_size=4, validation_data=(X_test, y_test))

# 📊 Step 10: Evaluate the model
loss, accuracy = model.evaluate(X_test, y_test)
print(f"\nTest Loss: {loss:.4f}")
print(f"Test Accuracy: {accuracy:.4f}")

# 🔍 Step 11: Classification report
y_pred = (model.predict(X_test) > 0.5).astype("int32")
print("\nClassification Report:\n", classification_report(y_test, y_pred))
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/100
# 5580/5580 ━━━━━━━━━━━━━━━━━━━━ 36s 5ms/step - accuracy: 0.7196 - loss: 0.5752 - val_accuracy: 0.8253 - val_loss: 0.4021
# Epoch 2/100
# 5580/5580 ━━━━━━━━━━━━━━━━━━━━ 31s 6ms/step - accuracy: 0.7839 - loss: 0.4778 - val_accuracy: 0.8349 - val_loss: 0.4032
# Epoch 3/100
# 5580/5580 ━━━━━━━━━━━━━━━━━━━━ 40s 5ms/step - accuracy: 0.7872 - loss: 0.4731 - val_accuracy: 0.8407 - val_loss: 0.3928
# Epoch 4/100
# 5580/5580 ━━━━━━━━━━━━━━━━━━━━ 30s 5ms/step - accuracy: 0.8068 - loss: 0.4581 - val_accuracy: 0.8290 - val_loss: 0.4139
# Epoch 5/100
# 5580/5580 ━━━━━━━━━━━━━━━━━━━━ 40s 5ms/step - accuracy: 0.8110 - loss: 0.4588 - val_accuracy: 0.8335 - val_loss: 0.4311
# Epoch 6/100
# 5580/5580 ━━━━━━━━━━━━━━━━━━━━ 30s 5ms/step - accuracy: 0.8177 - loss: 0.4525 - val_accuracy: 0.8210 - val_loss: 0.4156
# Epoch 7/100
# 5580/5580 ━━━━━━━━━━━━━━━━━━━━ 42s 5ms/step - accuracy: 0.8144 - loss: 0.4517 - val_accuracy: 0.8292 - val_loss: 0.4219
# Epoch 8/100
# 5580/5580 ━━━━━━━━━━━━━━━━━━━━ 41s 5ms/step - accuracy: 0.8146 - loss: 0.4490 - val_accuracy: 0.8434 - val_loss: 0.3954
# Epoch 9/100
# 5580/5580 ━━━━━━━━━━━━━━━━━━━━ 41s 6ms/step - accuracy: 0.8140 - loss: 0.4560 - val_accuracy: 0.8190 - val_loss: 0.4515
# Epoch 10/100
# 5580/5580 ━━━━━━━━━━━━━━━━━━━━ 31s 5ms/step - accuracy: 0.8138 - loss: 0.4536 - val_accuracy: 0.8344 - val_loss: 0.4032
# Epoch 11/100
# 5580/5580 ━━━━━━━━━━━━━━━━━━━━ 41s 5ms/step - accuracy: 0.8137 - loss: 0.4515 - val_accuracy: 0.8414 - val_loss: 0.3911
# Epoch 12/100
# 5580/5580 ━━━━━━━━━━━━━━━━━━━━ 30s 5ms/step - accuracy: 0.8204 - loss: 0.4408 - val_accuracy: 0.8188 - val_loss: 0.4298
# Epoch 13/100
# 5580/5580 ━━━━━━━━━━━━━━━━━━━━ 41s 5ms/step - accuracy: 0.8186 - loss: 0.4382 - val_accuracy: 0.8409 - val_loss: 0.3835
# Epoch 14/100
# 5580/5580 ━━━━━━━━━━━━━━━━━━━━ 31s 5ms/step - accuracy: 0.8171 - loss: 0.4346 - val_accuracy: 0.8389 - val_loss: 0.5362
# Epoch 15/100
# 5580/5580 ━━━━━━━━━━━━━━━━━━━━ 39s 5ms/step - accuracy: 0.8193 - loss: 0.4406 - val_accuracy: 0.8281 - val_loss: 3.1187
# Epoch 16/100
# 5580/5580 ━━━━━━━━━━━━━━━━━━━━ 46s 6ms/step - accuracy: 0.8186 - loss: 0.4439 - val_accuracy: 0.7437 - val_loss: 43.1310
# Epoch 17/100
# 5580/5580 ━━━━━━━━━━━━━━━━━━━━ 40s 6ms/step - accuracy: 0.8208 - loss: 0.4370 - val_accuracy: 0.7799 - val_loss: 34.9890
# Epoch 18/100
# 5580/5580 ━━━━━━━━━━━━━━━━━━━━ 31s 6ms/step - accuracy: 0.8159 - loss: 0.4398 - val_accuracy: 0.8190 - val_loss: 105.4175
# Epoch 19/100
# 5580/5580 ━━━━━━━━━━━━━━━━━━━━ 39s 5ms/step - accuracy: 0.8192 - loss: 0.4417 - val_accuracy: 0.8203 - val_loss: 48.1424
# Epoch 20/100
# 5580/5580 ━━━━━━━━━━━━━━━━━━━━ 31s 5ms/step - accuracy: 0.8189 - loss: 0.4417 - val_accuracy: 0.8387 - val_loss: 14.7025
# Epoch 21/100
# 5580/5580 ━━━━━━━━━━━━━━━━━━━━ 28s 5ms/step - accuracy: 0.8199 - loss: 0.4339 - val_accuracy: 0.8355 - val_loss: 9.0184
# Epoch 22/100
# 5580/5580 ━━━━━━━━━━━━━━━━━━━━ 43s 5ms/step - accuracy: 0.8198 - loss: 0.4369 - val_accuracy: 0.8342 - val_loss: 1.2016
# Epoch 23/100
# 5580/5580 ━━━━━━━━━━━━━━━━━━━━ 41s 5ms/step - accuracy: 0.8179 - loss: 0.4421 - val_accuracy: 0.8249 - val_loss: 0.4522
# Epoch 24/100
# 5580/5580 ━━━━━━━━━━━━━━━━━━━━ 40s 5ms/step - accuracy: 0.8271 - loss: 0.4246 - val_accuracy: 0.8450 - val_loss: 143.3198
# Epoch 25/100
# 5580/5580 ━━━━━━━━━━━━━━━━━━━━ 41s 5ms/step - accuracy: 0.8214 - loss: 0.4233 - val_accuracy: 0.8059 - val_loss: 32.3642
# Epoch 26/100
# 5580/5580 ━━━━━━━━━━━━━━━━━━━━ 39s 5ms/step - accuracy: 0.8129 - loss: 0.4396 - val_accuracy: 0.7717 - val_loss: 1086.6343
# Epoch 27/100
# 5580/5580 ━━━━━━━━━━━━━━━━━━━━ 42s 5ms/step - accuracy: 0.8189 - loss: 0.4272 - val_accuracy: 0.7833 - val_loss: 708.9824
# Epoch 28/100
# 5580/5580 ━━━━━━━━━━━━━━━━━━━━ 48s 6ms/step - accuracy: 0.8200 - loss: 0.4291 - val_accuracy: 0.8004 - val_loss: 356.6638
# Epoch 29/100
# 5580/5580 ━━━━━━━━━━━━━━━━━━━━ 38s 7ms/step - accuracy: 0.8237 - loss: 0.4305 - val_accuracy: 0.7677 - val_loss: 493.9374
# Epoch 30/100
# 5580/5580 ━━━━━━━━━━━━━━━━━━━━ 31s 5ms/step - accuracy: 0.8245 - loss: 0.4280 - val_accuracy: 0.7934 - val_loss: 207.3396
# Epoch 31/100
# 5580/5580 ━━━━━━━━━━━━━━━━━━━━ 42s 6ms/step - accuracy: 0.8210 - loss: 0.4366 - val_accuracy: 0.7763 - val_loss: 685.7554
# Epoch 32/100
# 5580/5580 ━━━━━━━━━━━━━━━━━━━━ 40s 6ms/step - accuracy: 0.8153 - loss: 0.4385 - val_accuracy: 0.7575 - val_loss: 634.6588
# Epoch 33/100
# 5580/5580 ━━━━━━━━━━━━━━━━━━━━ 31s 6ms/step - accuracy: 0.8216 - loss: 0.4301 - val_accuracy: 0.7647 - val_loss: 95.2807
# Epoch 34/100
# 5580/5580 ━━━━━━━━━━━━━━━━━━━━ 30s 5ms/step - accuracy: 0.8167 - loss: 0.4389 - val_accuracy: 0.7720 - val_loss: 25.5207
# Epoch 35/100
# 5580/5580 ━━━━━━━━━━━━━━━━━━━━ 38s 5ms/step - accuracy: 0.8168 - loss: 0.4328 - val_accuracy: 0.7636 - val_loss: 1.0400
# Epoch 36/100
# 5580/5580 ━━━━━━━━━━━━━━━━━━━━ 41s 5ms/step - accuracy: 0.8227 - loss: 0.4328 - val_accuracy: 0.7817 - val_loss: 1.1097
# Epoch 37/100
# 5580/5580 ━━━━━━━━━━━━━━━━━━━━ 43s 5ms/step - accuracy: 0.8257 - loss: 0.4281 - val_accuracy: 0.7633 - val_loss: 13.8177
# Epoch 38/100
# 5580/5580 ━━━━━━━━━━━━━━━━━━━━ 27s 5ms/step - accuracy: 0.8189 - loss: 0.4327 - val_accuracy: 0.7780 - val_loss: 44.3037
# Epoch 39/100
# 5580/5580 ━━━━━━━━━━━━━━━━━━━━ 27s 5ms/step - accuracy: 0.8257 - loss: 0.4224 - val_accuracy: 0.7369 - val_loss: 4.1252
# Epoch 40/100
# 5580/5580 ━━━━━━━━━━━━━━━━━━━━ 40s 5ms/step - accuracy: 0.8198 - loss: 0.4326 - val_accuracy: 0.8161 - val_loss: 0.6608
# Epoch 41/100
# 5580/5580 ━━━━━━━━━━━━━━━━━━━━ 41s 5ms/step - accuracy: 0.8227 - loss: 0.4272 - val_accuracy: 0.8093 - val_loss: 0.9952
# Epoch 42/100
# 5580/5580 ━━━━━━━━━━━━━━━━━━━━ 26s 5ms/step - accuracy: 0.8274 - loss: 0.4241 - val_accuracy: 0.7941 - val_loss: 1.2272
# Epoch 43/100
# 5580/5580 ━━━━━━━━━━━━━━━━━━━━ 44s 5ms/step - accuracy: 0.8279 - loss: 0.4262 - val_accuracy: 0.8228 - val_loss: 0.5147
# Epoch 44/100
# 5580/5580 ━━━━━━━━━━━━━━━━━━━━ 28s 5ms/step - accuracy: 0.8196 - loss: 0.4272 - val_accuracy: 0.7781 - val_loss: 1.0313
# Epoch 45/100
# 5580/5580 ━━━━━━━━━━━━━━━━━━━━ 39s 5ms/step - accuracy: 0.8209 - loss: 0.4283 - val_accuracy: 0.8231 - val_loss: 0.6305
# Epoch 46/100
# 5580/5580 ━━━━━━━━━━━━━━━━━━━━ 44s 5ms/step - accuracy: 0.8222 - loss: 0.4215 - val_accuracy: 0.8398 - val_loss: 0.4599
# Epoch 47/100
# 5580/5580 ━━━━━━━━━━━━━━━━━━━━ 26s 5ms/step - accuracy: 0.8248 - loss: 0.4224 - val_accuracy: 0.8045 - val_loss: 47.1680
# Epoch 48/100
# 5580/5580 ━━━━━━━━━━━━━━━━━━━━ 41s 5ms/step - accuracy: 0.8256 - loss: 0.4207 - val_accuracy: 0.8244 - val_loss: 39.9667
# Epoch 49/100
# 5580/5580 ━━━━━━━━━━━━━━━━━━━━ 44s 5ms/step - accuracy: 0.8300 - loss: 0.4238 - val_accuracy: 0.8176 - val_loss: 70.5585
# Epoch 50/100
# 5580/5580 ━━━━━━━━━━━━━━━━━━━━ 27s 5ms/step - accuracy: 0.8217 - loss: 0.4324 - val_accuracy: 0.7615 - val_loss: 38.4200
# Epoch 51/100
# 5580/5580 ━━━━━━━━━━━━━━━━━━━━ 40s 5ms/step - accuracy: 0.8215 - loss: 0.4275 - val_accuracy: 0.8219 - val_loss: 33.3433
# Epoch 52/100
# 5580/5580 ━━━━━━━━━━━━━━━━━━━━ 29s 5ms/step - accuracy: 0.8226 - loss: 0.4228 - val_accuracy: 0.7866 - val_loss: 169.1664
# Epoch 53/100
# 5580/5580 ━━━━━━━━━━━━━━━━━━━━ 28s 5ms/step - accuracy: 0.8225 - loss: 0.4276 - val_accuracy: 0.7842 - val_loss: 121.9065
# Epoch 54/100
# 5580/5580 ━━━━━━━━━━━━━━━━━━━━ 40s 5ms/step - accuracy: 0.8207 - loss: 0.4283 - val_accuracy: 0.8294 - val_loss: 6.4467
# Epoch 55/100
# 5580/5580 ━━━━━━━━━━━━━━━━━━━━ 43s 5ms/step - accuracy: 0.8238 - loss: 0.4236 - val_accuracy: 0.8125 - val_loss: 26.6065
# Epoch 56/100
# 5580/5580 ━━━━━━━━━━━━━━━━━━━━ 27s 5ms/step - accuracy: 0.8253 - loss: 0.4199 - val_accuracy: 0.8269 - val_loss: 47.1785
# Epoch 57/100
# 5580/5580 ━━━━━━━━━━━━━━━━━━━━ 41s 5ms/step - accuracy: 0.8340 - loss: 0.4223 - val_accuracy: 0.8063 - val_loss: 3.3903
# Epoch 58/100
# 5580/5580 ━━━━━━━━━━━━━━━━━━━━ 28s 5ms/step - accuracy: 0.8293 - loss: 0.4179 - val_accuracy: 0.8362 - val_loss: 0.4998
# Epoch 59/100
# 5580/5580 ━━━━━━━━━━━━━━━━━━━━ 30s 5ms/step - accuracy: 0.8223 - loss: 0.4232 - val_accuracy: 0.8256 - val_loss: 9.6716
# Epoch 60/100
# 5580/5580 ━━━━━━━━━━━━━━━━━━━━ 41s 5ms/step - accuracy: 0.8235 - loss: 0.4253 - val_accuracy: 0.8357 - val_loss: 2.1038
# Epoch 61/100
# 5580/5580 ━━━━━━━━━━━━━━━━━━━━ 32s 6ms/step - accuracy: 0.8201 - loss: 0.4343 - val_accuracy: 0.8023 - val_loss: 115.6447
# Epoch 62/100
# 5580/5580 ━━━━━━━━━━━━━━━━━━━━ 56s 9ms/step - accuracy: 0.8207 - loss: 0.4261 - val_accuracy: 0.8287 - val_loss: 0.8929
# Epoch 63/100
# 5580/5580 ━━━━━━━━━━━━━━━━━━━━ 43s 8ms/step - accuracy: 0.8230 - loss: 0.4279 - val_accuracy: 0.8194 - val_loss: 2.8105
# Epoch 64/100
# 5580/5580 ━━━━━━━━━━━━━━━━━━━━ 39s 7ms/step - accuracy: 0.8177 - loss: 0.4390 - val_accuracy: 0.7989 - val_loss: 2.7033
# Epoch 65/100
# 5580/5580 ━━━━━━━━━━━━━━━━━━━━ 40s 7ms/step - accuracy: 0.8236 - loss: 0.4238 - val_accuracy: 0.7916 - val_loss: 3.9368
# Epoch 66/100
# 5580/5580 ━━━━━━━━━━━━━━━━━━━━ 40s 7ms/step - accuracy: 0.8229 - loss: 0.4273 - val_accuracy: 0.8102 - val_loss: 1.3624
# Epoch 67/100
# 5580/5580 ━━━━━━━━━━━━━━━━━━━━ 40s 6ms/step - accuracy: 0.8272 - loss: 0.4208 - val_accuracy: 0.8240 - val_loss: 2.4485
# Epoch 68/100
# 5580/5580 ━━━━━━━━━━━━━━━━━━━━ 33s 6ms/step - accuracy: 0.8232 - loss: 0.4320 - val_accuracy: 0.8256 - val_loss: 0.6686
# Epoch 69/100
# 5580/5580 ━━━━━━━━━━━━━━━━━━━━ 32s 6ms/step - accuracy: 0.8227 - loss: 0.4288 - val_accuracy: 0.8122 - val_loss: 1.7688
# Epoch 70/100
# 5580/5580 ━━━━━━━━━━━━━━━━━━━━ 40s 6ms/step - accuracy: 0.8232 - loss: 0.4233 - val_accuracy: 0.8066 - val_loss: 2.4081
# Epoch 71/100
# 5580/5580 ━━━━━━━━━━━━━━━━━━━━ 30s 5ms/step - accuracy: 0.8293 - loss: 0.4227 - val_accuracy: 0.7866 - val_loss: 6.5210
# Epoch 72/100
# 5580/5580 ━━━━━━━━━━━━━━━━━━━━ 28s 5ms/step - accuracy: 0.8233 - loss: 0.4190 - val_accuracy: 0.7996 - val_loss: 3.2683
# Epoch 73/100
# 5580/5580 ━━━━━━━━━━━━━━━━━━━━ 30s 5ms/step - accuracy: 0.8228 - loss: 0.4252 - val_accuracy: 0.7342 - val_loss: 8.3557
# Epoch 74/100
# 5580/5580 ━━━━━━━━━━━━━━━━━━━━ 30s 5ms/step - accuracy: 0.8260 - loss: 0.4257 - val_accuracy: 0.7116 - val_loss: 6.1390
# Epoch 75/100
# 5580/5580 ━━━━━━━━━━━━━━━━━━━━ 39s 5ms/step - accuracy: 0.8249 - loss: 0.4298 - val_accuracy: 0.7557 - val_loss: 3.6322
# Epoch 76/100
# 5580/5580 ━━━━━━━━━━━━━━━━━━━━ 30s 5ms/step - accuracy: 0.8267 - loss: 0.4214 - val_accuracy: 0.7864 - val_loss: 6.0265
# Epoch 77/100
# 5580/5580 ━━━━━━━━━━━━━━━━━━━━ 27s 5ms/step - accuracy: 0.8296 - loss: 0.4210 - val_accuracy: 0.7998 - val_loss: 5.4487
# Epoch 78/100
# 5580/5580 ━━━━━━━━━━━━━━━━━━━━ 27s 5ms/step - accuracy: 0.8265 - loss: 0.4179 - val_accuracy: 0.7932 - val_loss: 7.6913
# Epoch 79/100
# 5580/5580 ━━━━━━━━━━━━━━━━━━━━ 30s 5ms/step - accuracy: 0.8211 - loss: 0.4264 - val_accuracy: 0.7642 - val_loss: 12.2686
# Epoch 80/100
# 5580/5580 ━━━━━━━━━━━━━━━━━━━━ 28s 5ms/step - accuracy: 0.8197 - loss: 0.4309 - val_accuracy: 0.7674 - val_loss: 7.1776
# Epoch 81/100
# 5580/5580 ━━━━━━━━━━━━━━━━━━━━ 27s 5ms/step - accuracy: 0.8247 - loss: 0.4280 - val_accuracy: 0.7806 - val_loss: 57.3430
# Epoch 82/100
# 5580/5580 ━━━━━━━━━━━━━━━━━━━━ 41s 5ms/step - accuracy: 0.8249 - loss: 0.4171 - val_accuracy: 0.7898 - val_loss: 17.8519
# Epoch 83/100
# 5580/5580 ━━━━━━━━━━━━━━━━━━━━ 27s 5ms/step - accuracy: 0.8241 - loss: 0.4273 - val_accuracy: 0.7797 - val_loss: 40.3853
# Epoch 84/100
# 5580/5580 ━━━━━━━━━━━━━━━━━━━━ 27s 5ms/step - accuracy: 0.8268 - loss: 0.4284 - val_accuracy: 0.7894 - val_loss: 22.6022
# Epoch 85/100
# 5580/5580 ━━━━━━━━━━━━━━━━━━━━ 41s 5ms/step - accuracy: 0.8308 - loss: 0.4194 - val_accuracy: 0.7982 - val_loss: 33.3456
# Epoch 86/100
# 5580/5580 ━━━━━━━━━━━━━━━━━━━━ 41s 5ms/step - accuracy: 0.8296 - loss: 0.4208 - val_accuracy: 0.7600 - val_loss: 156.4860
# Epoch 87/100
# 5580/5580 ━━━━━━━━━━━━━━━━━━━━ 27s 5ms/step - accuracy: 0.8303 - loss: 0.4228 - val_accuracy: 0.8018 - val_loss: 45.5393
# Epoch 88/100
# 5580/5580 ━━━━━━━━━━━━━━━━━━━━ 30s 5ms/step - accuracy: 0.8230 - loss: 0.4225 - val_accuracy: 0.7774 - val_loss: 3.2906
# Epoch 89/100
# 5580/5580 ━━━━━━━━━━━━━━━━━━━━ 27s 5ms/step - accuracy: 0.8260 - loss: 0.4278 - val_accuracy: 0.7728 - val_loss: 55.5860
# Epoch 90/100
# 5580/5580 ━━━━━━━━━━━━━━━━━━━━ 29s 5ms/step - accuracy: 0.8237 - loss: 0.4237 - val_accuracy: 0.8233 - val_loss: 3.5194
# Epoch 91/100
# 5580/5580 ━━━━━━━━━━━━━━━━━━━━ 48s 6ms/step - accuracy: 0.8323 - loss: 0.4217 - val_accuracy: 0.7556 - val_loss: 4.4518
# Epoch 92/100
# 5580/5580 ━━━━━━━━━━━━━━━━━━━━ 38s 7ms/step - accuracy: 0.8226 - loss: 0.4294 - val_accuracy: 0.7701 - val_loss: 5.1357
# Epoch 93/100
# 5580/5580 ━━━━━━━━━━━━━━━━━━━━ 35s 6ms/step - accuracy: 0.8192 - loss: 0.4341 - val_accuracy: 0.7659 - val_loss: 4.3587
# Epoch 94/100
# 5580/5580 ━━━━━━━━━━━━━━━━━━━━ 29s 5ms/step - accuracy: 0.8263 - loss: 0.4238 - val_accuracy: 0.7946 - val_loss: 2.4263
# Epoch 95/100
# 5580/5580 ━━━━━━━━━━━━━━━━━━━━ 32s 6ms/step - accuracy: 0.8231 - loss: 0.4283 - val_accuracy: 0.7952 - val_loss: 3.1329
# Epoch 96/100
# 5580/5580 ━━━━━━━━━━━━━━━━━━━━ 28s 5ms/step - accuracy: 0.8249 - loss: 0.4222 - val_accuracy: 0.7978 - val_loss: 5.4103
# Epoch 97/100
# 5580/5580 ━━━━━━━━━━━━━━━━━━━━ 31s 6ms/step - accuracy: 0.8268 - loss: 0.4261 - val_accuracy: 0.8029 - val_loss: 6.5259
# Epoch 98/100
# 5580/5580 ━━━━━━━━━━━━━━━━━━━━ 39s 5ms/step - accuracy: 0.8274 - loss: 0.4226 - val_accuracy: 0.8333 - val_loss: 0.7323
# Epoch 99/100
# 5580/5580 ━━━━━━━━━━━━━━━━━━━━ 40s 5ms/step - accuracy: 0.8281 - loss: 0.4234 - val_accuracy: 0.7950 - val_loss: 20.8468
# Epoch 100/100
# 5580/5580 ━━━━━━━━━━━━━━━━━━━━ 41s 5ms/step - accuracy: 0.8234 - loss: 0.4214 - val_accuracy: 0.8341 - val_loss: 3.7604
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8357 - loss: 0.7027
#
# Test Loss: 3.7604
# Test Accuracy: 0.8341
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.85      0.74      0.79      2348
#            1       0.83      0.90      0.86      3232
#
#     accuracy                           0.83      5580
#    macro avg       0.84      0.82      0.83      5580
# weighted avg       0.84      0.83      0.83      5580

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, BatchNormalization
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import classification_report

# 📂 Step 1: Load dataset
df = pd.read_csv('/content/student_depression_dataset.csv')

# 🧹 Step 2: Data Cleaning
df.replace('?', np.nan, inplace=True)   # Replace '?' with NaN
df.drop(['id', 'City', 'Profession', 'Degree'], axis=1, inplace=True)  # Drop unnecessary cols
df.dropna(inplace=True)  # Remove rows with missing values

# 🔤 Step 3: Encode categorical columns
le = LabelEncoder()
categorical_cols = ['Gender', 'Sleep Duration', 'Dietary Habits',
                    'Have you ever had suicidal thoughts ?',
                    'Family History of Mental Illness']
for col in categorical_cols:
    df[col] = le.fit_transform(df[col])

# 🎯 Step 4: Define features and label
X = df.drop('Depression', axis=1)
y = df['Depression']

# 🔄 Step 5: Normalize numerical features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# 🧪 Step 6: Train-test split
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# 🧠 Step 7: Build Deep ANN model with Batch Normalization
model = Sequential()

# Input Layer
model.add(Dense(128, activation='relu', input_dim=X_train.shape[1]))
model.add(BatchNormalization())  # Batch Normalization after the first layer

# Hidden Layer 1
model.add(Dense(64, activation='relu'))
model.add(BatchNormalization())  # Batch Normalization after second layer

# Hidden Layer 2
model.add(Dense(32, activation='relu'))
model.add(BatchNormalization())  # Batch Normalization after third layer

# Hidden Layer 3
model.add(Dense(16, activation='relu'))
model.add(BatchNormalization())  # Batch Normalization after fourth layer

# Hidden Layer 4
model.add(Dense(8, activation='relu'))
model.add(BatchNormalization())  # Batch Normalization after fifth layer

# Output Layer
model.add(Dense(1, activation='sigmoid'))  # Binary classification

# ⚙️ Step 8: Compile the model
model.compile(optimizer=Adam(), loss='binary_crossentropy', metrics=['accuracy'])

# 🏋️ Step 9: Train the model
history = model.fit(X_train, y_train, epochs=100, batch_size=4, validation_data=(X_test, y_test))

# 📊 Step 10: Evaluate the model
loss, accuracy = model.evaluate(X_test, y_test)
print(f"\nTest Loss: {loss:.4f}")
print(f"Test Accuracy: {accuracy:.4f}")

# 🔍 Step 11: Classification report
y_pred = (model.predict(X_test) > 0.5).astype("int32")
print("\nClassification Report:\n", classification_report(y_test, y_pred))
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/100
# 4026/4041 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7074 - loss: 0.5615
